# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

(train_data, train_targets), (test_data, test_targets) = tf.keras.datasets.boston_housing.load_data(
    path='boston_housing.npz', test_split=0.2, seed=42
)

# Now you can access the data
print("Training data shape:", train_data.shape)
print("Training targets shape:", train_targets.shape)
print("Test data shape:", test_data.shape)
print("Test targets shape:", test_targets.shape)
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step
# Training data shape: (404, 13)
# Training targets shape: (404,)
# Test data shape: (102, 13)
# Test targets shape: (102,)

# %%
# Set random seed
tf.random.set_seed(42)

# Build the model (3 layers, 100, 10, 1 units)
boston_pricing_1 = tf.keras.Sequential([
  tf.keras.layers.Dense(10),
  tf.keras.layers.Dense(100),
  tf.keras.layers.Dense(10),
  tf.keras.layers.Dense(1)
])

# Compile the model
boston_pricing_1.compile(loss=tf.keras.losses.mae,
                          optimizer=tf.keras.optimizers.Adam(),
                          metrics=['mae'])

# Fit the model for 200 epochs (same as insurance_model_2)
history_1=boston_pricing_1.fit(train_data, train_targets, epochs=200, verbose=0)

# %%
boston_pricing_1_loss, boston_pricing_1_mae = boston_pricing_1.evaluate(test_data, test_targets)
boston_pricing_1_loss, boston_pricing_1_mae
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 4.2001 - mae: 4.2001
# (4.200080871582031, 4.200080871582031)

# %%
pd.DataFrame(history_1.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs");

# %%
# Set random seed
tf.random.set_seed(42)

# Build the model (3 layers, 100, 10, 1 units)
boston_pricing_2 = tf.keras.Sequential([
  tf.keras.layers.Dense(10),
  tf.keras.layers.Dense(100),
  tf.keras.layers.Dense(100),
  tf.keras.layers.Dense(1)
])

# Compile the model
boston_pricing_2.compile(loss=tf.keras.losses.mae,
                          optimizer=tf.keras.optimizers.Adam(),
                          metrics=['mae'])

# Fit the model for 200 epochs (same as insurance_model_2)
history_2=boston_pricing_2.fit(train_data, train_targets, epochs=200, verbose=0)

boston_pricing_2_loss, boston_pricing_2_mae = boston_pricing_2.evaluate(test_data, test_targets)
boston_pricing_2_loss, boston_pricing_2_mae
# Out:
# 4/4 [==============================] - 0s 5ms/step - loss: 3.8705 - mae: 3.8705
# (3.8704655170440674, 3.8704655170440674)

# %%
pd.DataFrame(history_2.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs");
